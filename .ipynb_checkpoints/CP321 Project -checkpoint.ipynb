# %% [markdown]
# Name: Steven Tran AND Russell Goldman
#
# Student ID: 170574740 AND 160136650

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

h1 = "School Type"
h2 = "Percentage of Grade 3 Students Achieving the Provincial Standard in Reading"
h3 = "Percentage of Grade 3 Students Achieving the Provincial Standard in Writing"
h4 = "Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics"

h5 = "Percentage of Grade 6 Students Achieving the Provincial Standard in Reading"
h6 = "Percentage of Grade 6 Students Achieving the Provincial Standard in Writing"
h7 = "Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics"

h8 = 'Percentage of Children Who Live in Low-Income Households'
h9 = 'Percentage of Students Whose Parents Have Some University Education'



df = pd.read_excel("data/EQAO_Statistics.xlsx", sheet_name = "SIF_1718prelim_EQAO1718_EN")
df = df.loc[(df["School Level"] == "Elementary") & (df["School Type"] == "Catholic") | (df["School Type"] == "Public")]
df = df[[h1, h2, h3, h4, h5, h6, h7, h8, h9]]

dfGrade3 = df[[h1, h2, h3, h4, h8, h9]]
dfGrade3 = dfGrade3.groupby([h1]).mean()

dfGrade6 = df[[h1, h5, h6, h7, h8,h9]]
dfGrade6 = dfGrade6.groupby([h1]).mean()

# Newly added ---------------------------------------------------------------------------------------------

labels1 = ["IncomeDiff Reading - Grade 3", "incomeDiff Writing - Grade 3", "IncomeDiff Math - Grade 3", 
           "IncomeDiff Reading - Grade 6", "incomeDiff Writing - Grade 6", "IncomeDiff Math - Grade 6"]

for num in range(3):
    testing1 = []
    testing2 = []
    for num2 in range(2):
        testing1.append(100 - abs(dfGrade3.iat[num2,num] - dfGrade3.iat[num2, 3]))
        testing2.append(100 - abs(dfGrade6.iat[num2,num] - dfGrade6.iat[num2, 3]))
    dfGrade3[labels1[num]]     = testing1
    dfGrade6[labels1[num + 3]] = testing2
        

labels2 = ["EducationDiff Reading - Grade 3", "EducationDiff Writing - Grade 3", "EducationDiff Math - Grade 3",
           "EducationDiff Reading - Grade 6", "EducationDiff Writing - Grade 6", "EducationDiff Math - Grade 6"]

for num in range(3):
    testing1 = []
    testing2 = []
    for num2 in range(2):
        testing1.append(100 - abs(dfGrade3.iat[num2,num] - dfGrade3.iat[num2, 4]))
        testing2.append(100 - abs(dfGrade6.iat[num2,num] - dfGrade6.iat[num2, 4]))
    dfGrade3[labels2[num]]     = testing1
    dfGrade6[labels2[num + 3]] = testing2

# -------------------------------------------------------------------------------------------------------------

dfGrade3Income = dfGrade3[[labels1[0], labels1[1], labels1[2]]]
dfGrade6Income = dfGrade6[[labels1[3], labels1[4], labels1[5]]]

dfGrade3Education = dfGrade3[[labels2[0], labels2[1], labels2[2]]]
dfGrade6Education = dfGrade6[[labels2[3], labels2[4], labels2[5]]]



dfGrade3Income
# dfGrade3Education
# dfGrade6Income
# dfGrade6Education
# Out:
#              IncomeDiff Reading - Grade 3  incomeDiff Writing - Grade 3  \
# School Type
# Catholic                        40.255687                     43.076643
# Public                          46.314859                     49.996571
#
#              IncomeDiff Math - Grade 3
# School Type
# Catholic                     54.857742
# Public                       60.136865

# %%
# incomeCorrelationData = {
#     'School Board': [
#         'Public',
#         'Public',
#         'Public',
#         'Catholic',
#         'Catholic',
#         'Catholic'
#     ],
#     'Provincial Standards': [
#         'Gr 3 Reading',
#         'Gr 3 Writing',
#         'Gr 3 Math',
#         'Gr 3 Reading',
#         'Gr 3 Writing',
#         'Gr 3 Math'
#     ],
#     'Difference': [
#         50.3,
#         5.3,
#         25.6,
#         22.1,
#         12.0,
#         30.0
#     ]
# }

# educationCorrelationData = {
#     'School Board': [
#         'Public',
#         'Public',
#         'Public',
#         'Catholic',
#         'Catholic',
#         'Catholic'
#     ], 
#     'Provincial Standards': [
#         'Gr 3 Reading',
#         'Gr 3 Writing',
#         'Gr 3 Math',
#         'Gr 3 Reading',
#         'Gr 3 Writing',
#         'Gr 3 Math'
#     ],
#     'Difference': [
#         12.2,
#         54.2,
#         3.6,
#         16.3,
#         23.3,
#         8.2
#     ]
# }

# incomeCorrelationDF = pd.DataFrame(incomeCorrelationData)
# incomeCorrelationDF = incomeCorrelationDF.pivot("School Board", "Provincial Standards", "Difference")
incomeCorrelationDF = dfGrade3Income

# educationCorrelationDF = pd.DataFrame(educationCorrelationData)
# educationCorrelationDF = educationCorrelationDF.pivot("School Board", "Provincial Standards", "Difference")
educationCorrelationDF = dfGrade3Education

coolwarm = plt.cm.get_cmap('coolwarm')
warmcool = coolwarm.reversed()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sns.heatmap(incomeCorrelationDF, ax=ax1, vmin=0, vmax=100, cmap=warmcool)
sns.heatmap(educationCorrelationDF, ax=ax2, vmin=0, vmax=100, cmap=warmcool)
ax1.set_title('Correlation between High Income School Boards\n' + r'and Student Success', pad=20)
ax2.set_title('Correlation between Parent University Education\n' + r'and Student Success', pad=20)
plt.show()

# %%
# incomeCorrelationDF = pd.DataFrame(incomeCorrelationData)
# incomeCorrelationDF = incomeCorrelationDF.pivot("School Board", "Provincial Standards", "Difference")
incomeCorrelationDF = dfGrade6Income

# educationCorrelationDF = pd.DataFrame(educationCorrelationData)
# educationCorrelationDF = educationCorrelationDF.pivot("School Board", "Provincial Standards", "Difference")
educationCorrelationDF = dfGrade6Education

coolwarm = plt.cm.get_cmap('coolwarm')
warmcool = coolwarm.reversed()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sns.heatmap(incomeCorrelationDF, ax=ax1, vmin=0, vmax=100, cmap=warmcool)
sns.heatmap(educationCorrelationDF, ax=ax2, vmin=0, vmax=100, cmap=warmcool)
ax1.set_title('Correlation between High Income School Boards\n' + r'and Student Success', pad=20)
ax2.set_title('Correlation between Parent University Education\n' + r'and Student Success', pad=20)
plt.show()
