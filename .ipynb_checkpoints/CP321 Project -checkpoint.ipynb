# %% [markdown]
# # CP321 - Data Visualization Project
#
#
# **By:** Russell Goldman (160136650) & Steven Tran (170574740)
#
# **Dataset:** https://data.ontario.ca/dataset/school-information-and-student-demographics

# %% [markdown]
# ## Abstract
#
# The purpose of this study is to determine the strongest parental factor affecting K-12 Student Success. Using publically accessible Government data spanning 4917 rows, the data is processed and formatted into a Heatmap displaying the **Correlation between Medium-High Household Income and Student Success** as well as the **Correlation between Parental University Education and Student Success**.
#
# *As we eventually realized, the answer is more complex than previously imagined.*

# %% [markdown]
# ## Introduction and Motivation
#
# As Upper Year University Students, we recognize that our success is largely in our own hands. Most of us live away from home year long and work part-time jobs or internships to save up or pay for student fees. We are mature enough to know how to seek out academic support when needed and make our own complex decisions.
#
# In our K-12 years however when most students were too young or immature to make complex academic decisions, parents that could support their children would had played a vital role in their success.
#
# We were curious to explore which parental traits had a stronger correlation to K-12 student success. The two traits of focus were *Percentage of Parents with Medium-High Household Income* and *Percentage of Parents with University Education*.

# %% [markdown]
# ## Data Set Description, Statistics, and Processing
#
# ### Description
#
# We used a dataset provided by the Government of Ontario on *School information and student demographics*.
#
# The main columns of interest were ...
#
# - School Type
# - Percentage of Grade 3 Students Achieving the Provincial Standard in Reading
# - Percentage of Grade 3 Students Achieving the Provincial Standard in Writing
# - Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics
# - Percentage of Grade 6 Students Achieving the Provincial Standard in Reading
# - Percentage of Grade 6 Students Achieving the Provincial Standard in Writing
# - Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics
# - Percentage of Children Who Live in Low-Income Households
#     - *Inverted to calculate Percentage of Children Who Live in Medium-High Income Households*
# - Percentage of Students Whose Parents Have Some University Education
#
# ### Statistics
#
# All of our chosen columns beside *School Type* were percentage values.
# As such, our data was automatically normalized as they were in the range of 0 to 100. Thus all of our values were on the same scale and could be immediately analyzed.
#
# ### Processing
#
# At this point in time, we began to explore the best ways to visualize our data. We looked at the possibilities of using a Scatter Plot, Correlogram, or a Heatmap. After experimenting, we came to the conclusion that a **Heatmap** would be the best way to illustrate our problem.
#
# To conform to the plotting requirements of a Heatmap using the Seaborn library, we had to organize our data in a way that would be compatible.
#
# The code below accomplishes that task.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

# CONSTANT Column names
h1 = "School Type"
h2 = "Percentage of Grade 3 Students Achieving the Provincial Standard in Reading"
h3 = "Percentage of Grade 3 Students Achieving the Provincial Standard in Writing"
h4 = "Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics"

h5 = "Percentage of Grade 6 Students Achieving the Provincial Standard in Reading"
h6 = "Percentage of Grade 6 Students Achieving the Provincial Standard in Writing"
h7 = "Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics"

h8 = 'Percentage of Children Who Live in Low-Income Households'
h9 = 'Percentage of Students Whose Parents Have Some University Education'

df = pd.read_excel("data/EQAO_Statistics.xlsx", sheet_name = "SIF_1718prelim_EQAO1718_EN")
df = df.loc[(df["School Level"] == "Elementary") & (df["School Type"] == "Catholic") | (df["School Type"] == "Public")]
df = df[[h1, h2, h3, h4, h5, h6, h7, h8, h9]]

dfGrade3 = df[[h1, h2, h3, h4, h8, h9]]
dfGrade3 = dfGrade3.groupby([h1]).mean()

dfGrade6 = df[[h1, h5, h6, h7, h8,h9]]
dfGrade6 = dfGrade6.groupby([h1]).mean()

# Creating 4 new Dataframes for each correlation
labels = ["Reading", "Writing", "Mathematics"] 
dfGrade3Income    = pd.DataFrame(index = dfGrade3.index)
dfGrade6Income    = pd.DataFrame(index = dfGrade6.index)
dfGrade3Education = pd.DataFrame(index = dfGrade3.index)
dfGrade6Education = pd.DataFrame(index = dfGrade6.index)


for num in range(3):
    # Initally Empty Arrays - Will become the columns in the new Dataframe
    IncomeDiff3    = []
    IncomeDiff6    = []
    EducationDiff3 = []
    EducationDiff6 = []
    for num2 in range(2):
        # Calculation for Income difference = 100 - absolute(child% - low household income%)
        IncomeDiff3.append(100 - abs(dfGrade3.iat[num2,num] - (100 - dfGrade3.iat[num2, 3])))
        IncomeDiff6.append(100 - abs(dfGrade6.iat[num2,num] - (100 - dfGrade6.iat[num2, 3])))
        
        # Calculation for Education Difference = 100 - absolute(child % - University Education %)
        EducationDiff3.append(100 - abs(dfGrade3.iat[num2,num] - dfGrade3.iat[num2, 4]))
        EducationDiff6.append(100 - abs(dfGrade6.iat[num2,num] - dfGrade6.iat[num2, 4]))
        
    # Creating the new columns in the DataFrames
    dfGrade3Income[labels[num]]    = IncomeDiff3
    dfGrade6Income[labels[num]]    = IncomeDiff6
    dfGrade3Education[labels[num]] = EducationDiff3
    dfGrade6Education[labels[num]] = EducationDiff6

# -------------------------------------------------------------------------------------------------------------

# ------Testing --------
# print(dfGrade3)
# print(dfGrade3Income)
# dfGrade3Education
# dfGrade6Income
# dfGrade6Education

# %% [markdown]
# ## Visualization
#
# To visualize the strongest determining factor on K-12 Student Success, we created Heatmaps for both **Medium-High Household Income** and **Parent University Education**. These were correlated with data from both **Grade 3 and Grade 6 Public and Catholic School Averages** across Reading, Writing, and Mathematics.
#
# ### Grade 3 Student Success Heatmap

# %%
coolwarm = plt.cm.get_cmap('coolwarm')
warmcool = coolwarm.reversed()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sns.heatmap(dfGrade3Income, ax=ax1, vmin=0, vmax=100, cmap=warmcool)
sns.heatmap(dfGrade3Education, ax=ax2, vmin=0, vmax=100, cmap=warmcool)
ax1.set_title('Correlation between Medium-High Household Income\n' + r'and Student Success (Grade 3)', pad=20)
ax2.set_title('Correlation between Parent University Education\n' + r'and Student Success (Grade 3)', pad=20)
plt.show()

# %% [markdown]
# ### Grade 6 Student Success Heatmap

# %%
coolwarm = plt.cm.get_cmap('coolwarm')
warmcool = coolwarm.reversed()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sns.heatmap(dfGrade6Income, ax=ax1, vmin=0, vmax=100, cmap=warmcool)
sns.heatmap(dfGrade6Education, ax=ax2, vmin=0, vmax=100, cmap=warmcool)
ax1.set_title('Correlation between Medium-High Household Income\n' + r'and Student Success (Grade 6)', pad=20)
ax2.set_title('Correlation between Parent University Education\n' + r'and Student Success (Grade 6)', pad=20)
plt.show()

# %% [markdown]
# ## Conclusion
#
# Our visualization showed that the Correlation between Medium-High Household Income and Student Success was more dominant in Reading and Writing whereas the Correlation between Parent University Education and Student Success was more dominant in Mathematics.
#
# This was an interesting conclusion as the answer turned out to be much more complex than we initially expected.
#
# In conclusion, we thoroughly enjoyed the opportunity to utilize our newly gained Data Visualization skills to answer some thought provoking real-world questions alongside reputable data sets.
